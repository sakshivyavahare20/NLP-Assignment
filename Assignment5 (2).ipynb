# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
from nltk.corpus import wordnet as wn

# %%
def get_wordnet_relations(word):
    results = {
        "synonyms": set(),
        "antonyms": set(),
        "hypernyms": set(),
        "hyponyms": set()
    }

    for synset in wn.synsets(word):
        # Synonyms
        for lemma in synset.lemmas():
            results["synonyms"].add(lemma.name())

            # Antonyms
            if lemma.antonyms():
                results["antonyms"].add(lemma.antonyms()[0].name())

        # Hypernyms
        for hypernym in synset.hypernyms():
            for lemma in hypernym.lemmas():
                results["hypernyms"].add(lemma.name())

        # Hyponyms
        for hyponym in synset.hyponyms():
            for lemma in hyponym.lemmas():
                results["hyponyms"].add(lemma.name())

    return results

# %%
word = "happy"
relations = get_wordnet_relations(word)

print("Word:", word)
print("Synonyms:", relations["synonyms"])
print("Antonyms:", relations["antonyms"])
print("Hypernyms:", relations["hypernyms"])
print("Hyponyms:", relations["hyponyms"])
# Out:
# Word: happy
# Synonyms: {'felicitous', 'glad', 'happy', 'well-chosen'}
# Antonyms: {'unhappy'}
# Hypernyms: set()
# Hyponyms: set()

# %%
def analyze_text(text):
    words = set(text.lower().split())
    analysis = {}

    for word in words:
        analysis[word] = get_wordnet_relations(word)

    return analysis

# %%
text = "The happy child felt joyful but not sad."
results = analyze_text(text)

for word, relations in results.items():
    print(f"\n🔹 Word: {word}")
    print("  Synonyms:", relations["synonyms"])
    print("  Antonyms:", relations["antonyms"])
    print("  Hypernyms:", relations["hypernyms"])
    print("  Hyponyms:", relations["hyponyms"])
# Out:
# 🔹 Word: child
#   Synonyms: {'small_fry', 'minor', 'child', 'tiddler', 'nipper', 'tike', 'youngster', 'nestling', 'baby', 'shaver', 'kid', 'fry', 'tyke'}
#   Antonyms: {'parent'}
#   Hypernyms: {'somebody', 'soul', 'individual', 'person', 'someone', 'descendant', 'juvenile', 'mortal', 'offspring', 'juvenile_person', 'issue', 'progeny', 'descendent'}
#   Hyponyms: {'toddler', 'man-child', 'waif', 'child_prodigy', 'silly', 'army_brat', 'picaninny', 'male_offspring', 'female_offspring', 'foster-child', 'sprog', 'tot', 'rapscallion', 'street_child', 'scalawag', 'stepchild', 'wonder_child', 'peanut', 'scallywag', 'babe', 'buster', 'kindergartener', 'monkey', 'foster_child', 'infant', 'baby', 'preschooler', 'yearling', 'infant_prodigy', 'bambino', 'urchin', 'imp', 'changeling', 'piccaninny', 'poster_child', 'pickaninny', 'kindergartner', 'fosterling', 'bairn', 'rascal', 'kiddy', 'orphan', 'scamp'}
#
# 🔹 Word: happy
#   Synonyms: {'felicitous', 'glad', 'happy', 'well-chosen'}
#   Antonyms: {'unhappy'}
#   Hypernyms: set()
#   Hyponyms: set()
#
# 🔹 Word: but
#   Synonyms: {'simply', 'only', 'but', 'just', 'merely'}
#   Antonyms: set()
#   Hypernyms: set()
#   Hyponyms: set()
#
# 🔹 Word: not
#   Synonyms: {'not', 'non'}
#   Antonyms: set()
#   Hypernyms: set()
#   Hyponyms: set()
#
# 🔹 Word: felt
#   Synonyms: {'felt_up', 'palpate', 'matt-up', 'matte', 'experience', 'find', 'finger', 'sense', 'felt', 'mat_up', 'mat', 'feel', 'matte_up'}
#   Antonyms: set()
#   Hypernyms: {'cloth', 'change', 'seem', 'reason_out', 'fabric', 'cover', 'believe', 'go_through', 'reason', 'perceive', 'entangle', 'search', 'conclude', 'regain', 'material', 'see', 'think', 'touch', 'be', 'snarl', 'seek', 'look_for', 'consider', 'tangle', 'appear', 'conceive', 'comprehend', 'experience', 'find', 'textile', 'mat', 'look'}
#   Hyponyms: {'pride', 'sadden', 'feel_like_a_million', 'plume', 'beam', 'radiate', 'shine', 'nurse', 'sympathise', 'chafe', 'recapture', 'repent', 'fly_high', 'pride_oneself', 'congratulate', 'sympathize', 'see_red', 'burn', 'scrabble', 'grope_for', 'rejoice', 'smoulder', 'harbour', 'crawl', 'hold', 'smolder', 'cool_off', 'entertain', 'fume', 'anger', 'take_pride', 'rue', 'glow', 'feel_like_a_million_dollars', 'suffocate', 'harbor', 'incline', 'die', 'joy', 'regret', 'suffer'}
#
# 🔹 Word: the
#   Synonyms: set()
#   Antonyms: set()
#   Hypernyms: set()
#   Hyponyms: set()
#
# 🔹 Word: sad.
#   Synonyms: set()
#   Antonyms: set()
#   Hypernyms: set()
#   Hyponyms: set()
#
# 🔹 Word: joyful
#   Synonyms: {'elated', 'jubilant', 'joyful', 'gleeful'}
#   Antonyms: {'sorrowful'}
#   Hypernyms: set()
#   Hyponyms: set()
